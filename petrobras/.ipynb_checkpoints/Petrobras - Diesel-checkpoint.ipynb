# %%
import pandas as pd
import tabula 
from urllib import request
import os
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.parse import urljoin
import re
from PyPDF2 import PdfFileReader
import matplotlib.pyplot as plt
import yfinance as yf

# %%
url = "https://petrobras.com.br/pt/nossas-atividades/precos-de-venda-as-distribuidoras/gasolina-e-diesel/"
html = urlopen(url)
bs = BeautifulSoup(html, "html.parser")

# DIESEL
links = []
for x in bs.find_all("a", href = True):
    if re.search(re.compile("diesel", flags = re.IGNORECASE), str(x)):
        links.append(x["href"])

# %%
root = "https://petrobras.com.br/"
link_final_diesel = links[2][9:]
link_diesel = root + link_final_diesel

# %%
pag_pdf = tabula.read_pdf(link_diesel, pages = "all", multiple_tables=True)
pag_pdf
# Out:
# [                    0                     1           2           3   \
#  0                LOCAL  MODALIDADE\rDE VENDA  01.08.2019  05.09.2019
#  1       Araucária (PR)                   EXA    2.062,10    2.114,60
#  2       Araucária (PR)                   LPA    2.064,10    2.116,60
#  3         Barueri (SP)                   EXA    2.088,90    2.141,40
#  4         Barueri (SP)                   LPA    2.093,20    2.145,70
#  ..                 ...                   ...         ...         ...
#  72     Vila Velha (ES)                   LTM    2.131,40    2.183,90
#  73        Vitória (ES)                   EXA    2.186,40    2.238,90
#  74        Vitória (ES)                   LTM    2.131,40    2.183,90
#  75  Volta Redonda (RJ)                   EXA    2.115,40    2.167,90
#  76  Volta Redonda (RJ)                   LPC    2.126,40    2.178,90
#
#              4           5           6           7           8           9   \
#  0   13.09.2019  19.09.2019  25.10.2019  01.11.2019  19.11.2019  01.12.2019
#  1     2.168,80    2.260,40    2.225,60    2.157,80    2.183,90    2.183,90
#  2     2.170,80    2.262,40    2.227,60    2.160,10    2.186,20    2.186,20
#  3     2.195,60    2.287,20    2.252,40    2.184,60    2.210,70    2.210,70
#  4     2.199,90    2.291,50    2.256,70    2.188,90    2.215,00    2.212,60
#  ..         ...         ...         ...         ...         ...         ...
#  72    2.238,10    2.329,70    2.294,90    2.227,10    2.253,20    2.253,20
#  73    2.293,10    2.384,70    2.349,90    2.282,10    2.308,20    2.308,20
#  74    2.238,10    2.329,70    2.294,90    2.227,10    2.253,20    2.253,20
#  75    2.222,10    2.313,70    2.278,90    2.211,10    2.237,20    2.237,20
#  76    2.233,10    2.324,70    2.289,90    2.222,10    2.248,20    2.248,20
#
#              10          11          12          13          14          15  \
#  0   04.12.2019  21.12.2019  14.01.2020  24.01.2020  31.01.2020  06.02.2020
#  1     2.227,30    2.303,70    2.253,60    2.161,90    2.096,40    2.004,70
#  2     2.229,60    2.306,00    2.255,90    2.164,20    2.098,70    2.007,00
#  3     2.254,10    2.328,60    2.278,50    2.186,80    2.121,30    2.029,60
#  4     2.256,00    2.330,50    2.280,40    2.188,70    2.123,20    2.031,50
#  ..         ...         ...         ...         ...         ...         ...
#  72    2.296,60    2.361,30    2.206,50    2.114,80    2.049,30    1.957,60
#  73    2.351,60    2.416,30    2.261,50    2.169,80    2.104,30    2.012,60
#  74    2.296,60    2.361,30    2.206,50    2.114,80    2.049,30    1.957,60
#  75    2.280,60    2.390,90    2.340,80    2.249,10    2.183,60    2.091,90
#  75    1.910,00    1.946,60
#  76    1.921,00    1.957,60
#
#  [77 rows x 18 columns],
#                      0                     1           2           3   \
#  0                LOCAL  MODALIDADE\rDE VENDA  21.08.2020  22.08.2020
#  1       Araucária (PR)                   EXA    1.953,50    1.953,50
#  2       Araucária (PR)                   LPA    1.955,80    1.955,80
#  3         Barueri (SP)                   EXA    1.978,40    1.978,40
#  4         Barueri (SP)                   LPA    1.980,30    1.980,30
#  ..                 ...                   ...         ...         ...
#  72     Vila Velha (ES)                   LTM    1.906,40    1.906,40
#  73        Vitória (ES)                   EXA         NaN         NaN
#  74        Vitória (ES)                   LTM    1.906,40    1.906,40
#  75  Volta Redonda (RJ)                   EXA    2.040,70    2.040,70
#  76  Volta Redonda (RJ)                   LPC    2.051,70    2.051,70
#
#              4           5           6           7           8           9   \
#  0   26.08.2020  03.09.2020  09.09.2020  11.09.2020  30.09.2020  01.10.2020
#  1     1.953,50    1.835,70    1.743,50    1.621,20    1.670,10    1.670,10
#  2     1.955,80    1.838,00    1.745,80    1.623,50    1.672,40    1.672,40
#  3     1.978,40    1.860,60    1.768,40    1.646,10    1.695,00    1.695,00
#  4     1.980,30    1.862,50    1.770,30    1.648,00    1.696,90    1.696,90
#  ..         ...         ...         ...         ...         ...         ...
#  72    1.906,40    1.788,60    1.696,40    1.574,10    1.623,00    1.623,00
#  73         NaN         NaN         NaN         NaN         NaN         NaN
#  74    1.906,40    1.788,60    1.696,40    1.574,10    1.623,00    1.623,00
#  75    2.040,70    1.922,90    1.830,70    1.708,40    1.757,30    1.757,30
#  76    2.051,70    1.933,90    1.841,70    1.719,40    1.768,30    1.768,30
#
#              10          11          12          13          14          15  \
#  0   10.10.2020  27.10.2020  01.11.2020  12.11.2020  26.11.2020  01.12.2020
#  1     1.754,70    1.684,40    1.684,40    1.769,90    1.856,70    1.856,70
#  2     1.757,00    1.686,70    1.686,70    1.772,20    1.859,00    1.859,00
#  3     1.779,60    1.709,30    1.709,30    1.794,80    1.881,60    1.881,60
#  4     1.781,50    1.711,20    1.711,20    1.796,70    1.883,50    1.883,50
#  ..         ...         ...         ...         ...         ...         ...
#  72    1.707,60    1.637,30    1.637,30    1.722,80    1.809,60    1.809,60
#  73         NaN         NaN         NaN         NaN         NaN         NaN
#  74    1.707,60    1.637,30    1.637,30    1.722,80    1.809,60    1.809,60
#  75    1.841,90    1.771,60    1.771,60    1.857,10    1.943,90    1.943,90
#  76    1.852,90    1.782,60    1.782,60    1.868,10    1.954,90    1.954,90
#
#              16          17
#  0   16.12.2020  29.12.2020
#  1     1.931,60    2.009,50
#  2     1.933,90    2.011,80
#  3     1.956,50    2.034,40
#  4     1.958,40    2.036,30
#  ..         ...         ...
#  72    1.884,50    1.962,40
#  73         NaN         NaN
#  74    1.884,50    1.962,40
#  75    2.018,80    2.096,70
#  76    2.029,80    2.107,70
#
#  [77 rows x 18 columns],
#                      0                     1           2           3   \
#  0                LOCAL  MODALIDADE\rDE VENDA  01.01.2021  19.01.2021
#  1       Araucária (PR)                   EXA    2.009,50    2.009,50
#  2       Araucária (PR)                   LPA    2.011,80    2.011,80
#  3         Barueri (SP)                   EXA    2.034,40    2.034,40
#  4         Barueri (SP)                   LPA    2.036,30    2.036,30
#  ..                 ...                   ...         ...         ...
#  72     Vila Velha (ES)                   LTM    1.962,40    1.962,40
#  73        Vitória (ES)                   EXA         NaN    2.031,10
#  74        Vitória (ES)                   LTM    1.962,40    1.962,40
#  75  Volta Redonda (RJ)                   EXA    2.096,70    2.096,70
#  76  Volta Redonda (RJ)                   LPC    2.107,70    2.107,70
#
#              4           5           6           7           8           9   \
#  0   27.01.2021  01.02.2021  09.02.2021  19.02.2021  01.03.2021  02.03.2021
#  1     2.100,70    2.100,70    2.225,50    2.601,00    2.601,00    2.730,40
#  2     2.103,00    2.103,00    2.227,80    2.603,30    2.603,30    2.732,70
#  3     2.125,60    2.125,60    2.250,40    2.580,90    2.580,90    2.710,30
#  4     2.127,50    2.127,50    2.252,30    2.582,80    2.582,80    2.712,20
#  ..         ...         ...         ...         ...         ...         ...
#  72    2.053,60    2.053,60    2.178,40    2.508,90    2.508,90    2.638,30
#  73    2.122,30    2.118,80    2.243,60    2.574,10    2.569,40    2.698,80
#  74    2.053,60    2.053,60    2.178,40    2.508,90    2.508,90    2.638,30
#  75    2.187,90    2.187,90    2.312,70    2.643,20    2.643,20    2.772,60
#  76    2.198,90    2.198,90    2.323,70    2.654,20    2.654,20    2.783,60
#
#              10          11          12          13          14          15  \
#  0   09.03.2021  25.03.2021  01.04.2021  10.04.2021  16.04.2021  01.05.2021
#  1     2.879,10    2.764,70    2.764,70    2.682,10    2.782,20    2.726,60
#  2     2.881,40    2.767,00    2.767,00    2.684,40    2.784,50    2.728,90
#  3     2.859,00    2.744,60    2.744,60    2.662,00    2.762,10    2.706,50
#  4     2.860,90    2.746,50    2.746,50    2.663,90    2.764,00    2.708,40
#  ..         ...         ...         ...         ...         ...         ...
#  72    2.787,00    2.672,60    2.672,60    2.590,00    2.690,10    2.634,50
#  73    2.847,50    2.733,10    2.749,90    2.667,30    2.767,40    2.713,20
#  74    2.787,00    2.672,60    2.672,60    2.590,00    2.690,10    2.634,50
#  75    2.921,30    2.806,90    2.806,90    2.724,30    2.824,40    2.768,80
#  76    2.932,30    2.817,90    2.817,90    2.735,30    2.835,40    2.779,80
#
#              16          17
#  0   01.06.2021  19.06.2021
#  1     2.726,60    2.706,60
#  2     2.728,90    2.708,90
#  3     2.706,50    2.706,50
#  4     2.708,40    2.708,40
#  ..         ...         ...
#  72    2.634,50    2.684,50
#  73    2.715,20    2.765,20
#  74    2.634,50    2.684,50
#  75    2.768,80    2.768,80
#  76    2.779,80    2.779,80
#
#  [77 rows x 18 columns],
#                       0                     1           2           3  \
#  0                LOCAL  MODALIDADE\rDE VENDA  01.07.2021  06.07.2021
#  1       Araucária (PR)                   EXA    2.706,60    2.808,90
#  2       Araucária (PR)                   LPA    2.708,90    2.811,20
#  3         Barueri (SP)                   EXA    2.706,50    2.808,80
#  4         Barueri (SP)                   LPA    2.708,40    2.810,70
#  ..                 ...                   ...         ...         ...
#  72     Vila Velha (ES)                   LTM    2.684,50    2.786,80
#  73        Vitória (ES)                   EXA    2.763,80    2.866,10
#  74        Vitória (ES)                   LTM    2.684,50    2.786,80
#  75  Volta Redonda (RJ)                   EXA    2.768,80    2.871,10
#  76  Volta Redonda (RJ)                   LPC    2.779,80    2.882,10
#
#               4           5
#  0   10.07.2021  01.08.2021
#  1     2.808,90    2.808,90
#  2     2.811,20    2.811,20
#  3     2.808,80    2.808,80
#  4     2.810,70    2.810,70
#  ..         ...         ...
#  72    2.786,80    2.786,80
#  73    2.866,10    2.866,70
#  74    2.786,80    2.786,80
#  75    2.871,10    2.871,10
#  76    2.882,10    2.882,10
#
#  [77 rows x 6 columns],
#                   0                     1           2           3           4   \
#  0             LOCAL  MODALIDADE\rDE VENDA  01.08.2019  05.09.2019  13.09.2019
#  1    Araucária (PR)                   EXA    2.098,20    2.150,70    2.204,90
#  2    Araucária (PR)                   LPA    2.100,20    2.152,70    2.206,90
#  3      Barueri (SP)                   EXA    2.133,60    2.186,10    2.240,30
#  4      Barueri (SP)                   LPA    2.137,90    2.190,40    2.244,60
#  ..              ...                   ...         ...         ...         ...
#  64  Uberlândia (MG)                   LCT         NaN         NaN         NaN
#  65  Vila Velha (ES)                   EXA    2.231,10    2.283,60    2.337,80
#  66  Vila Velha (ES)                   LTM    2.176,10    2.228,60    2.282,80
#  67     Vitória (ES)                   EXA    2.231,10    2.283,60    2.337,80
#  68     Vitória (ES)                   LTM    2.176,10    2.228,60    2.282,80
#
#              5           6           7           8           9           10  \
#  0   19.09.2019  25.10.2019  01.11.2019  19.11.2019  01.12.2019  04.12.2019
#  1     2.296,50    2.261,70    2.193,90    2.220,00    2.220,00    2.263,40
#  2     2.298,50    2.263,70    2.196,20    2.222,30    2.222,30    2.265,70
#  3     2.331,90    2.297,10    2.229,30    2.255,40    2.255,40    2.298,80
#  4     2.336,20    2.301,40    2.233,60    2.259,70    2.257,30    2.300,70
#  ..         ...         ...         ...         ...         ...         ...
#  64         NaN         NaN         NaN         NaN         NaN         NaN
#  65    2.429,40    2.394,60    2.326,80    2.352,90    2.352,90    2.396,30
#  66    2.374,40    2.339,60    2.271,80    2.297,90    2.297,90    2.341,30
#  67    2.429,40    2.394,60    2.326,80    2.352,90    2.352,90    2.396,30
#  68    2.374,40    2.339,60    2.271,80    2.297,90    2.297,90    2.341,30
#
#              11          12          13          14          15          16  \
#  0   21.12.2019  14.01.2020  24.01.2020  31.01.2020  06.02.2020  29.02.2020
#  1     2.342,60    2.272,50    2.180,80    2.115,30    2.023,60    1.923,10
#  2     2.344,90    2.274,80    2.183,10    2.117,60    2.025,90    1.925,40
#  3     2.376,10    2.306,00    2.214,30    2.148,80    2.057,10    1.956,60
#  4     2.378,00    2.307,90    2.216,20    2.150,70    2.059,00    1.958,50
#  ..         ...         ...         ...         ...         ...         ...
#  64         NaN         NaN         NaN         NaN         NaN         NaN
#  65    2.459,80    2.284,80    2.193,10    2.127,60    2.035,90    1.935,40
#  66    2.404,80    2.229,80    2.138,10    2.072,60    1.980,90    1.880,40
#  67    2.459,80    2.284,80    2.193,10    2.127,60    2.035,90    1.935,40
#  68    2.404,80    2.229,80    2.138,10    2.072,60    1.980,90    1.880,40
#
#              17
#  0   01.03.2020
#  1     1.923,10
#  2     1.925,40
#  3     1.956,60
#  4     1.958,50
#  ..         ...
#  64         NaN
#  65    1.935,40
#  4      Barueri (SP)                   LPA    2.007,80    2.007,80    2.007,80
#  ..              ...                   ...         ...         ...         ...
#  64  Uberlândia (MG)                   LCT         NaN         NaN         NaN
#  65  Vila Velha (ES)                   EXA         NaN         NaN         NaN
#  66  Vila Velha (ES)                   LTM    1.929,70    1.929,70    1.929,70
#  67     Vitória (ES)                   EXA         NaN         NaN         NaN
#  68     Vitória (ES)                   LTM    1.929,70    1.929,70    1.929,70
#
#              5           6           7           8           9           10  \
#  0   03.09.2020  09.09.2020  11.09.2020  30.09.2020  01.10.2020  10.10.2020
#  1     1.854,60    1.762,40    1.640,10    1.689,00    1.689,00    1.773,60
#  2     1.856,90    1.764,70    1.642,40    1.691,30    1.691,30    1.775,90
#  3     1.888,10    1.795,90    1.673,60    1.722,50    1.722,50    1.807,10
#  4     1.890,00    1.797,80    1.675,50    1.724,40    1.724,40    1.809,00
#  ..         ...         ...         ...         ...         ...         ...
#  64         NaN         NaN         NaN         NaN         NaN         NaN
#  65         NaN         NaN         NaN         NaN         NaN         NaN
#  66    1.811,90    1.719,70    1.597,40    1.646,30    1.646,30    1.730,90
#  67         NaN         NaN         NaN         NaN         NaN         NaN
#  68    1.811,90    1.719,70    1.597,40    1.646,30    1.646,30    1.730,90
#
#              11          12          13          14          15          16  \
#  0   27.10.2020  01.11.2020  12.11.2020  26.11.2020  01.12.2020  16.12.2020
#  1     1.703,30    1.703,30    1.788,80    1.875,60    1.875,60    1.950,50
#  2     1.705,60    1.705,60    1.791,10    1.877,90    1.877,90    1.952,80
#  3     1.736,80    1.736,80    1.822,30    1.909,10    1.909,10    1.984,00
#  4     1.738,70    1.738,70    1.824,20    1.911,00    1.911,00    1.985,90
#  ..         ...         ...         ...         ...         ...         ...
#  64         NaN         NaN         NaN         NaN         NaN         NaN
#  65         NaN         NaN         NaN         NaN         NaN         NaN
#  66    1.660,60    1.660,60    1.746,10    1.832,90    1.832,90    1.907,80
#  67         NaN         NaN         NaN         NaN         NaN         NaN
#  68    1.660,60    1.660,60    1.746,10    1.832,90    1.832,90    1.907,80
#
#              17
#  0   29.12.2020
#  1     2.028,40
#  2     2.030,70
#  3     2.061,90
#  4     2.063,80
#  ..         ...
#  64         NaN
#  65         NaN
#  66    1.985,70
#  67         NaN
#  68    1.985,70
#
#  [69 rows x 18 columns],
#                   0                     1           2           3           4   \
#  0             LOCAL  MODALIDADE\rDE VENDA  01.01.2021  15.01.2021  27.01.2021
#  1    Araucária (PR)                   EXA    2.028,40    2.028,40    2.119,60
#  2    Araucária (PR)                   LPA    2.030,70    2.030,70    2.121,90
#  3      Barueri (SP)                   EXA    2.061,90    2.061,90    2.153,10
#  4      Barueri (SP)                   LPA    2.063,80    2.063,80    2.155,00
#  ..              ...                   ...         ...         ...         ...
#  64  Uberlândia (MG)                   LCT         NaN    2.176,40    2.267,60
#  65  Vila Velha (ES)                   EXA         NaN         NaN         NaN
#  66  Vila Velha (ES)                   LTM    1.985,70    1.985,70    2.076,90
#  67     Vitória (ES)                   EXA         NaN         NaN         NaN
#  68     Vitória (ES)                   LTM    1.985,70    1.985,70    2.076,90
#
#              5           6           7           8           9           10  \
#  0   01.02.2021  09.02.2021  19.02.2021  01.03.2021  02.03.2021  09.03.2021
#  1     2.119,60    2.244,40    2.619,90    2.619,90    2.749,30    2.898,00
#  2     2.121,90    2.246,70    2.622,20    2.622,20    2.751,60    2.900,30
#  3     2.153,10    2.277,90    2.608,40    2.608,40    2.737,80    2.886,50
#  4     2.155,00    2.279,80    2.610,30    2.610,30    2.739,70    2.888,40
#  ..         ...         ...         ...         ...         ...         ...
#  64    2.267,60    2.392,40    2.722,90    2.722,90    2.852,30    3.001,00
#  65         NaN         NaN         NaN         NaN         NaN         NaN
#  66    2.076,90    2.201,70    2.532,20    2.532,20    2.661,60    2.810,30
#  67         NaN         NaN         NaN         NaN         NaN         NaN
#  68    2.076,90    2.201,70    2.532,20    2.532,20    2.661,60    2.810,30
#
#              11          12          13          14          15          16  \
#  0   25.03.2021  01.04.2021  10.04.2021  16.04.2021  01.05.2021  01.06.2021
#  1     2.783,60    2.783,60    2.701,00    2.801,10    2.745,50    2.745,50
#  2     2.785,90    2.785,90    2.703,30    2.803,40    2.747,80    2.747,80
#  3     2.772,10    2.772,10    2.689,50    2.789,60    2.734,00    2.734,00
#  4     2.774,00    2.774,00    2.691,40    2.791,50    2.735,90    2.735,90
#  ..         ...         ...         ...         ...         ...         ...
#  64    2.886,60    2.887,10    2.804,50    2.904,60    2.849,00    2.849,00
#  65         NaN         NaN         NaN         NaN         NaN         NaN
#  66    2.695,90    2.695,90    2.613,30    2.713,40    2.657,80    2.657,80
#  67         NaN         NaN         NaN         NaN         NaN         NaN
#  68    2.695,90    2.695,90    2.613,30    2.713,40    2.657,80    2.657,80
#
#              17
#  0   19.06.2021
#  1     2.725,50
#  2     2.727,80
#  3     2.734,00
#  4     2.735,90
#  ..         ...
#  64    2.849,00
#  65         NaN
#  66    2.707,80
#  67         NaN
#  68    2.707,80
#
#  [69 rows x 18 columns],
#                    0                     1           2           3           4  \
#  0             LOCAL  MODALIDADE\rDE VENDA  01.07.2021  06.07.2021  10.07.2021
#  1    Araucária (PR)                   EXA    2.725,50    2.827,80    2.827,80
#  2    Araucária (PR)                   LPA    2.727,80    2.830,10    2.830,10
#  3      Barueri (SP)                   EXA    2.734,00    2.836,30    2.836,30
#  4      Barueri (SP)                   LPA    2.735,90    2.838,20    2.838,20
#  ..              ...                   ...         ...         ...         ...
#  64  Uberlândia (MG)                   LCT    2.849,00    2.951,30    2.951,30
#  65  Vila Velha (ES)                   EXA         NaN         NaN         NaN
#  66  Vila Velha (ES)                   LTM    2.707,80    2.810,10    2.810,10
#  67     Vitória (ES)                   EXA         NaN         NaN         NaN
#  68     Vitória (ES)                   LTM    2.707,80    2.810,10    2.810,10
#
#               5
#  0   01.08.2021
#  1     2.827,80
#  2     2.830,10
#  3     2.836,30
#  4     2.838,20
#  ..         ...
#  64    2.951,30
#  65         NaN
#  66    2.810,10
#  67         NaN
#  68    2.810,10
#
#  [69 rows x 6 columns],
#        0                        1  \
#  0   NaN      Modalidade de Venda
#  1   NaN                      NaN
#  2   EXA             Ex-Ponto “A”
#  3   NaN                      NaN
#  4   NaN                      NaN
#  5   LPA     Livre para o Armazém
#  6   NaN                      NaN
#  7   NaN   Livre no Compartimento
#  8   NaN                      NaN
#  9   LCT      de Carga do Veículo
#  10  NaN                      NaN
#  11  NaN                Recebedor
#  12  LPC  Livre para Carregamento
#  13  NaN     Entrega no Tanque de
#  14  ETM                      NaN
#  15  NaN         Destino Marítimo
#  16  NaN        Livre no Terminal
#  17  LTM                      NaN
#  18  NaN                 Marítimo
#  19  NaN                      NaN
#  20  NaN     Entregue no Terminal
#  21  ETT                      NaN
#  22  NaN                Terrestre
#  23  NaN                      NaN
#  24  NaN     Entrega no Tanque de
#  25  ETD                      NaN
#  26  NaN                  Destino
#
#                                                      2
#  0                                           Descrição
#  1   Entrega por duto a serviço da COMPRADORA, inte...
#  2                                                 NaN
#  3   dos Ativos, ambos dentro da Área Operacional d...
#  4   Entrega por duto, ou trecho de duto, a serviço...
#  5                                                 NaN
#  6   Interconexão dos Ativos fora da Área Operacion...
#  7                                                 NaN
#  8   Entrega diretamente no Veiculo Recebedor estac...
#  9                                                 NaN
#  10               Carregamento a serviço da PETROBRAS.
#  11                                                NaN
#  12  Entrega diretamente na Estação de Carregamento...
#  13  Entrega no terminal de destino a partir de nav...
#  14                                                NaN
#  15                descarga contratada pela PETROBRAS.
#  16  Entrega no terminal de destino a partir de nav...
#  17                                                NaN
#  18               descarga contratada pela COMPRADORA.
#  19  Entrega diretamente na Estação de Descarregame...
#  20                                                NaN
#  21  descarga do Veículo de Entrega, ou diretamente...
#  22                                                NaN
#  23                   por duto a serviço da PETROBRAS.
#  24                                                NaN
#  25  Entrega do produto se dá mediante troca de pro...
#  26                                                NaN  ]

# %%
agrupado = pd.DataFrame()
for dataframe in range(0,len(pag_pdf)):
    
    if len(pag_pdf[dataframe]) > 25:        
        df = pag_pdf[dataframe]
        
        for line_num, line in enumerate(pag_pdf[dataframe].iloc[:,0]):
            if line == "LOCAL":
                linha_datas = df.iloc[line_num, :]
        
        df2 = df.dropna(subset = [df.columns[0]])
#         print(linha_datas)
#         print(df2.head(20))
        try:
            df2.columns = linha_datas
        except:
            print(f"erro página {dataframe}")
            continue
        df2 = df2.reset_index(drop = True)
        df2.drop(0, axis = 0, inplace = True)
        df3 = pd.melt(df2, id_vars = df2.columns[:2], value_vars = df2.columns[2:])
        df3.columns = ["LOCAL", "MODALIDADE", "DATA", "VALOR"]
        agrupado = pd.concat([agrupado, df3], axis = 0)
# Out:
# erro página 10

# %%
agrupado.dropna(subset = ["VALOR"], inplace=True)

agrupado.loc[:,"VALOR"] = agrupado["VALOR"].str.replace(".", "")
agrupado.loc[:,"VALOR"] = agrupado["VALOR"].apply(lambda x: float(x.replace(",", "."))/1000)
agrupado.loc[:,"DATA"] = agrupado["DATA"].apply(lambda x: pd.to_datetime(x, format = "%d.%m.%Y"))
# Out:
# <ipython-input-9-c1e379ac5244>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   agrupado.loc[:,"VALOR"] = agrupado["VALOR"].str.replace(".", "")

# %%
agrupado["PRODUTO"] = 0

for line_num, line in enumerate(agrupado["DATA"]):
    data_corrente = line
    try:
        data_proxima = agrupado.iloc[line_num + 1, 2]
        if data_corrente < data_proxima:
            agrupado.iloc[line_num, 4] = "S500"
    except:
        continue

# %%
agrupado[agrupado["PRODUTO"] == "S500"]
